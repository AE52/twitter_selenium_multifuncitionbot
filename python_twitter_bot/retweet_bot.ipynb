# %%
#kutuphane aktarimi
import random
import time
from selenium import webdriver
from selenium.webdriver.common.by import By

#site adresine giris
driver = webdriver.Chrome()
driver.get("https://twitter.com/i/flow/login")

time.sleep(2)

#username girisi
username = driver.find_element(By.TAG_NAME, "input")
username.send_keys("ae52ww")

#butona basim
all_buttons = driver.find_elements(
    By.XPATH, "//div[@role='button']"
)
all_buttons[-2].click()

time.sleep(2)

#password kismi doldurma
password = driver.find_element(
    By.XPATH, "//input[@type='password']"
)
password.send_keys("Deneme123")

time.sleep(2)


all_buttons = driver.find_elements(
    By.XPATH, "//div[@role='button']"
)
all_buttons[-1].click()

time.sleep(2)

# timeline aramasi 
keyword = "fenerbahçe"
driver.get("https://twitter.com/search?q=" + keyword + "&src=typed_query")

time.sleep(5) 



n_scrolls = 5

for scroll in range(n_scrolls):
    # 1. retweet butonuna basim 
    retweet = driver.find_elements(
        By.XPATH, "//div[@data-testid='retweet']"
    )
    driver.execute_script("arguments[0].click();", retweet[-1])
    
    # 2. retweet butonuna basim                 
    time.sleep(2)
    retweet_con = driver.find_elements(
        By.XPATH, "//div[@data-testid='retweetConfirm']"
    )
    driver.execute_script("arguments[0].click();", retweet_con[-1])
    
    time.sleep(2)
    like = driver.find_elements(
        By.XPATH, "//div[@data-testid='like']"
    )
    driver.execute_script("arguments[0].click();", like[-1])
    
    #sayfayi kaydirma islemi
    time.sleep(2)
    driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
    time.sleep(2)

    #----AE52----
